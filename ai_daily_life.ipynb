# %% [markdown]
# # Task 1: AI in Daily Life Observation
#
# Name: Vaishnavi Landage
#
# Internship: Growfinix AI Internship
#
# Objective:
# Understand how AI works in daily life applications
# such as Google Maps, YouTube and Voice Assistants.

# %% [markdown]
# Google Maps Observation
#
# Input:
# User enters destination
#
# Processing:
# Maps analyzes traffic, distance and roads
#
# Decision:
# Selects best route
#
# Output:
# Route and estimated arrival time

# %% [markdown]
# Input:
# Videos watched by user
#
# Processing:
# YouTube analyzes watch history
#
# Decision:
# Predicts user interests
#
# Output:
# Recommended videos

# %% [markdown]
# Input:
# Voice command
#
# Processing:
# Speech converted into text
#
# Decision:
# Recognizes user request
#
# Output:
# Provides relevant answer

# %%
interest = input("Enter your interest: ")

if interest.lower() == "cybersecurity":
    print("Recommended: Ethical Hacking Course")
else:
    print("Recommended: Technology Videos")
# Out:
# Enter your interest: cybersecurity
# Recommended: Ethical Hacking Course

# %%
videos = ["Python", "Linux", "Cybersecurity"]

for video in videos:
    print(video)
# Out:
# Python
# Linux
# Cybersecurity

# %%
interests = ["Python", "Cybersecurity", "Linux"]

print(interests)
# Out:
# ['Python', 'Cybersecurity', 'Linux']
